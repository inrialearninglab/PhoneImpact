# %%
import pandas as pd

Or = [0.00236, 4051, 13870]
Cuivre = [17.32, 3922, 11451]
Fer = [1090, 3423, 10155]

df = pd.DataFrame(
    [Or, Cuivre, Fer],
    columns=["Métal produit", "Minerais extrait", "Matière extraite"],
    index=["Or", "Cuivre", "Fer"]
)

df = df.transpose()

# %%
import matplotlib.pyplot as plt
from pywaffle import Waffle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-8afc4b96b3b0> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 from pywaffle import Waffle
#
# ModuleNotFoundError: No module named 'pywaffle'

# %%
fig = plt.figure(FigureClass=Waffle, 
                 rows=30, columns=30,
                 values=df.Fer, 
                 colors=colors,
                 labels=label,
                 figsize = (15,6),
                 legend={'loc':'upper right',
                         'bbox_to_anchor': (1.32, 1),
                        })
plt.tight_layout()
plt.title("Extraction du fer", size=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-aae2d7807284> in <module>
# ----> 1 fig = plt.figure(FigureClass=Waffle,
#       2                  rows=30, columns=30,
#       3                  values=df.Fer,
#       4                  colors=colors,
#       5                  labels=label,
#
# NameError: name 'Waffle' is not defined

# %%
from pywaffle import Waffle

colors = ['#99ff99', '#66b3ff', '#ff9999']

fig = plt.figure(FigureClass=Waffle, 
                 rows=30, columns=30,
                 values=df.Or, 
                 colors=colors,
                 labels=label,
                 figsize = (15,6),
                 legend={'loc':'upper right',
                         'bbox_to_anchor': (1.32, 1),
                        })
plt.tight_layout()
plt.title("Extraction de l'or", size=20)
plt.show()
# Out:
# <Waffle size 1500x600 with 1 Axes>

# %%
colors = ['#deb305', '#66b3ff', '#99ff99']
label = [df.index[i] + f": {int(df.Cuivre[i])} tonnes" for i in range(len(df.Cuivre))]

fig = plt.figure(FigureClass=Waffle, 
                 rows=30, columns=30,
                 values=df.Cuivre, 
                 colors=colors,
                 labels=label,
                 figsize = (15,6),
                 legend={'loc':'upper right',
                         'bbox_to_anchor': (1.5, 1),
                        })
plt.tight_layout()
plt.title("Extraction du cuivre", size=20, pad=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-371b87e119f5> in <module>
#       1 colors = ['#deb305', '#66b3ff', '#99ff99']
# ----> 2 label = [df.index[i] + f": {int(df.Cuivre[i])} tonnes" for i in range(len(df.Cuivre))]
#       3
#       4 fig = plt.figure(FigureClass=Waffle,
#       5                  rows=30, columns=30,
#
# NameError: name 'df' is not defined
